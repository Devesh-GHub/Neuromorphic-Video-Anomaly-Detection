# %%
import torch
import os
import sys

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))
from models.conv_lstm_autoencoder import ConvLSTMAutoencoder

# %%
# Dummy input tensor
B = 2       # batch size
T = 8       # sequence length
C = 3
H = W = 128

x = torch.randn(B, T, C, H, W)

# %%
model = ConvLSTMAutoencoder(
    input_channels=3,
    hidden_dim=64
)

# %%
with torch.no_grad():
    out = model(x)

print("Input shape :", x.shape)
print("Output shape:", out.shape)
# Out:
# Input shape : torch.Size([2, 8, 3, 128, 128])
# Output shape: torch.Size([2, 8, 3, 128, 128])
