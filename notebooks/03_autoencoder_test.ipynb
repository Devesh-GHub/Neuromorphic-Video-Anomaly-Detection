# %%
import torch
import os
import sys

sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "..")))
from models.simple_autoencoder import SimpleAutoencoder

# %%
model = SimpleAutoencoder()
print(model)
# Out:
# SimpleAutoencoder(
#   (encoder): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (decoder): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(2, 2), stride=(2, 2))
#     (1): ReLU()
#     (2): ConvTranspose2d(64, 32, kernel_size=(2, 2), stride=(2, 2))
#     (3): ReLU()
#     (4): ConvTranspose2d(32, 3, kernel_size=(2, 2), stride=(2, 2))
#     (5): Sigmoid()
#   )
# )

# %%
# Batch size = 4
x = torch.randn(4, 3, 128, 128)  # Example input tensor with batch size 4 and image size 128x128 with 3 channels (RGB)

print("Input shape:", x.shape)
# Out:
# Input shape: torch.Size([4, 3, 128, 128])

# %%
with torch.no_grad():
    output = model(x)

print("Output shape:", output.shape)
# Out:
# Output shape: torch.Size([4, 3, 128, 128])

# %%
assert x.shape == output.shape
print("✅ Input and output shapes match!")
# Out:
# ✅ Input and output shapes match!
