# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("Device:", "cuda" if torch.cuda.is_available() else "cpu")
# Out:
# PyTorch version: 2.8.0+cpu
# CUDA available: False
# Device: cpu

# %%
import os
os.chdir('..')  # Change to project root
print("Current working directory:", os.getcwd())
# Out:
# Current working directory: c:\Users\Devesh\OneDrive\Desktop\project

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('.'))

from src.train import main
main()
# Out:
# Epoch [1] Loss: 0.000869
# Epoch [2] Loss: 0.000036
# Epoch [3] Loss: 0.000021
# Epoch [4] Loss: 0.000015
# Epoch [5] Loss: 0.000012
# Epoch [6] Loss: 0.000010
# Epoch [7] Loss: 0.000009
# Epoch [8] Loss: 0.000008
# Epoch [9] Loss: 0.000007
# Epoch [10] Loss: 0.000007
# Epoch [11] Loss: 0.000006
# Epoch [12] Loss: 0.000006
# Epoch [13] Loss: 0.000006
# Epoch [14] Loss: 0.000006
# Epoch [15] Loss: 0.000005
# Epoch [16] Loss: 0.000006
# Epoch [17] Loss: 0.000005
# Epoch [18] Loss: 0.000005
# Epoch [19] Loss: 0.000005
# Epoch [20] Loss: 0.000005
